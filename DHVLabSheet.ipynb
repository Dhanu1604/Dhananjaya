# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanu1604/Dhananjaya/blob/main/DHVLabSheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
cars_data=pd.read_csv("/content/Toyota.csv",index_col = 0,na_values = ['??','???'])

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1421 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1436 non-null   object
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 123.4+ KB

# %%
##SACTTER PLOT

# %%
plt.scatter(cars_data['Age'],cars_data['Price'],c = 'red')
plt.title('Sactter plot of Price vs Age ')
plt.ylabel('Age(month)')
plt.ylabel('Price(Euros)')
plt.show()

# %%
cars_data.dropna(axis=0,inplace=True)
cars_data
# Out:
#       Price   Age       KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90       1.0          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90       0.0          0  2000      3
# 5     12950  32.0  61000.0   Diesel   90       0.0          0  2000      3
# ...     ...   ...      ...      ...  ...       ...        ...   ...    ...
# 1423   7950  80.0  35821.0   Petrol   86       0.0          1  1300      3
# 1424   7750  73.0  34717.0   Petrol   86       0.0          0  1300      3
# 1429   8950  78.0  24000.0   Petrol   86       1.0          1  1300      5
# 1430   8450  80.0  23000.0   Petrol   86       0.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 3       1165
# ...

# %%
##HISTOGRAM

# %%
plt.hist(cars_data['KM'])
plt.hist(cars_data['KM'],color='green',edgecolor='white',bins=30)
plt.title('Histoigram of KM')
plt.xlabel('kilometers')
plt.ylabel('Frequency')
plt.show()

# %%
##BAR PLOT

# %%
index = [1,2,3]
counts = [10,20,30]
fueltype = ['petrol','diesel','electric']

# %%
plt.bar(index,counts,color=['red','blue','cyan'])
plt.title('Bar plot of fuel type')
plt.xlabel('Fue types')
plt.ylabel('Frequency')
plt.xticks(index,fueltype,rotation=60)
plt.show()

# %%
fig, axes = plt.subplots(1,2,figsize=(10,4))
x = np.linspace(0.1,100,1000)

# %%
axes[0].plot(x,x**2,x,np.exp(x))
axes[0].set_title("Normal scale")
# Out:
# Text(0.5, 1.0, 'Normal scale')

# %%
axes[1].plot(x,x**2,x,np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale(y)");

# %%
fig,ax = plt.subplots(figsize=(10,4))

# %%
ax.plot(x, x*2, x, x*3, lw=2)

# %%
ax.plot(x, x*2, x, x*3, lw=2)

# %%
fig , ax= plt.subplots(figsize=(10,4))
ax.plot(x,x*2,x,x*3,lw=2)
ax.set_xticks([1,2,3,4,5])
ax.set_xticklabels([r'$\alpha$',r'$\beta$',r'$\gamma$',r'$\delta$',r'$\epsilon$'],fontsize=18)

yticks = [0,50,100,150]
ax.set_yticks(yticks)
ax.set_yticklabels(["$%.1f$" % y for y in yticks], fontsize=18);

# %%
ax.plot(x,x**2,x,np.exp(x))
ax.set_title("scientific notation")
# Out:
# Text(0.5, 1.0, 'scientific notation')

# %%
from matplotlib import ticker
formatter=ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax.yaxis.set_major_formatter(formatter)

# %%
ax.set_yticks([0,50,100,150])

# %%
ax.set_yticks([0,50,100,150])

# %%
import matplotlib
matplotlib.rcParams['xtick.major.pad']=5
matplotlib.rcParams['ytick.major.pad']=5

# %%
ax.set_xlabel("x")
ax.set_ylabel("y");

# %%
ax.plot(x,x**2,x,np.exp(x))
ax.set_yticks([0,50,100,150])

# %%
ax.set_title("label and axis spacing")
# Out:
# Text(0.5, 1.0, 'label and axis spacing')

# %%
ax.xaxis.labelpad = 5
ax.yaxis.labelpad = 5

# %%
ax.set_xlabel("x")
ax.set_ylabel("y");

# %%
fig,ax = plt.subplots(1,1)

# %%
ax.set_title("title")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(4.444444444444445, 0.5, 'y')

# %%
fig,axes=plt.subplots(1,2,figsize=(10,3))

# %%
axes[0].plot(x,x*2,x,x*3,lw=2)
axes[0].grid(True)

# %%
axes[1].plot(x,x*2,x,x*3,lw=2)
axes[1].grid(color='b',alpha=0.5,linestyle='dashed',linewidth=0.5)
